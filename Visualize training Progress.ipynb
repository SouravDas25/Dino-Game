# %% [markdown]
# ## Visualize the progress of training
# All paths are relative.

# %%
import time
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (15, 9)
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import pandas as pd
import  os

def get_current_path(*args):
    filepath = os.path.join(*args)
    return os.path.join(os.path.dirname(os.path.realpath("__file__")), filepath)

start = 0
interval = 10
scores_df = pd.read_csv(get_current_path('objects','scores_df.csv'))
mean_scores = pd.DataFrame(columns =['score'])
actions_df = pd.read_csv(get_current_path('objects','actions_df.csv'))
max_scores = pd.DataFrame(columns =['max_score'])
q_max_scores = pd.DataFrame(columns =['q_max'])
q_max_df = pd.read_csv(get_current_path('objects','q_values.csv'))

# %%
while interval <= len(scores_df):
    mean_scores.loc[len(mean_scores)] = (scores_df.loc[start:interval].mean()['scores'])
    max_scores.loc[len(max_scores)] = (scores_df.loc[start:interval].max()['scores'])
    start = interval
    interval = interval + 10

# %%
start = 0
interval = 1000
while interval <=len(q_max_df):
    q_max_scores.loc[len(q_max_scores)] = (q_max_df.loc[start:interval].mean()['actions'])
    start = interval
    interval = interval + 1000

# %%
mean_scores.plot()
max_scores.plot()
q_max_scores.plot()
# Out:
# <AxesSubplot:>

# %%
q_max_df.loc[start:interval].mean()
import pickle
import random
import cv2

# %%
with open('objects/' + 'D' + '.pkl', 'rb') as f:
        D = pickle.load(f)

# %%
minibatch = D
len(D)
# Out:
# 10000

# %%
inputs = np.zeros((43, 80, 80, 1)) 

fig = plt.figure(figsize=(15, 15))

rows = 4
columns = 2

count = 0

for i in range(5238, 9000):
    state_t = minibatch[i][0]  # 4D stack of images
    action_t = minibatch[i][1]  # This is action index
    reward_t = minibatch[i][2]  # reward at state_t due to action_t
    state_t1 = minibatch[i][3]  # next state
    is_over = minibatch[i][4] 
    if reward_t == -1 :
        st = np.reshape(state_t, (80,80))
        st1 = np.reshape(state_t1, (80,80))
        count = count + 1
        fig.add_subplot(rows, columns, count)
        plt.imshow(st, cmap = plt.cm.binary)
        plt.axis("off")
        count = count + 1
        fig.add_subplot(rows, columns, count)
        plt.imshow(st1, cmap = plt.cm.binary)
        plt.axis("off")
        print(action_t,i)

print(action_t,i)
# Out:
# 0 5238
# 1 5239
# 1 5261
# 0 5262
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yc/zc5q2wq12qx488l09vvhhfrr0000gn/T/ipykernel_58535/373990862.py in <module>
#      18         st1 = np.reshape(state_t1, (80,80))
#      19         count = count + 1
# ---> 20         fig.add_subplot(rows, columns, count)
#      21         plt.imshow(st, cmap = plt.cm.binary)
#      22         plt.axis("off")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     779             projection_class, pkw = self._process_projection_requirements(
#     780                 *args, **kwargs)
# --> 781             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     782             key = (projection_class, pkw)
#     783         return self._add_axes_internal(ax, key)
#
# ...
